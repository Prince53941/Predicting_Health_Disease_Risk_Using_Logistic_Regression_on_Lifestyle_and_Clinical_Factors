# %% [markdown]
# **Important Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# **Data Read**

# %%
df = pd.read_csv('heart_data.csv')

# %% [markdown]
# **Data Tabular Analysis**

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %%
df.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790             0         Yes    Male        60-64  Hispanic      Yes
# 319791             0          No    Male        35-39  Hispanic       No
# 319792             0          No  Female        45-49  Hispanic       No
# 319793             0          No  Female        25-29  Hispanic       No
# 319794             0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
df.sample(5)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 53730            No  31.09      No              No     No               0
# 51695            No  29.63     Yes              No     No               0
# 103942           No  26.63      No              No     No               3
# 68789            No  22.96      No              No     No               0
# 205127           No  25.69      No              No     No               0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# 53730              0          No  Female       25-29  Hispanic       No
# 51695              0          No  Female       60-64     White       No
# 103942             1          No    Male       60-64     White       No
# 68789              0          No    Male       70-74     White       No
# 205127             0          No  Female       50-54     White       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'Sex',
#        'Diabetic', 'SleepTime', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df['Diabetic'].value_counts()
# Out:
# Diabetic
# 2    269653
# 1     40802
# 4      6781
# 3      2559
# Name: count, dtype: int64

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 0    292422
# 1     27373
# Name: count, dtype: int64

# %%
df['Smoking'].value_counts()
# Out:
# Smoking
# 0    187887
# 1    131908
# Name: count, dtype: int64

# %%
df['AlcoholDrinking'].value_counts()
# Out:
# AlcoholDrinking
# 0    298018
# 1     21777
# Name: count, dtype: int64

# %%
df['Stroke'].value_counts()
# Out:
# Stroke
# 0    307726
# 1     12069
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# 0    167805
# 1    151990
# Name: count, dtype: int64

# %%
df['Asthma'].value_counts()
# Out:
# Asthma
# 0    276923
# 1     42872
# Name: count, dtype: int64

# %%
df['KidneyDisease'].value_counts()
# Out:
# KidneyDisease
# 0    308016
# 1     11779
# Name: count, dtype: int64

# %%
df['SkinCancer'].value_counts()
# Out:
# SkinCancer
# 0    289976
# 1     29819
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'Sex',
#        'Diabetic', 'SleepTime', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df['Sex'] = df['Sex'].map({'Male': 1, 'Female': 0})
df['HeartDisease'] = df['HeartDisease'].map({'Yes': 1, 'No': 0})
df['Diabetic'] = df['Diabetic'].map({'Yes': 1, 'No': 2, 'Yes (during pregnancy)': 3, 'No, borderline diabetes': 4})
df['Smoking'] = df['Smoking'].map({'Yes': 1, 'No': 0})
df['AlcoholDrinking'] = df['AlcoholDrinking'].map({'Yes': 1, 'No': 0})
df['SkinCancer'] = df['SkinCancer'].map({'Yes': 1, 'No': 0})
df['Asthma'] = df['Asthma'].map({'Yes': 1, 'No': 0})
df['KidneyDisease'] = df['KidneyDisease'].map({'Yes': 1, 'No': 0})
df['Stroke'] = df['Stroke'].map({'Yes': 1, 'No': 0})

# %%
df = df.drop(['PhysicalHealth', 'MentalHealth', 'DiffWalking',  'AgeCategory',
             'GenHealth' , 'Race','PhysicalActivity' ], axis=1)

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  Sex  Diabetic  \
# 0             0  16.60        1                0       0    0         1
# 1             0  20.34        0                0       1    0         2
# 2             0  26.58        1                0       0    1         1
# 3             0  24.21        0                0       0    0         2
# 4             0  23.71        0                0       0    0         2
#
#    SleepTime  Asthma  KidneyDisease  SkinCancer
# 0          5       1              0           1
# 1          7       0              0           0
# 2          8       1              0           0
# 3          6       0              0           1
# 4          8       0              0           0

# %% [markdown]
# **Data Visualization**

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'HeartDisease'}>,
#         <Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'Smoking'}>],
#        [<Axes: title={'center': 'AlcoholDrinking'}>,
#         <Axes: title={'center': 'Stroke'}>,
#         <Axes: title={'center': 'Sex'}>],
#        [<Axes: title={'center': 'Diabetic'}>,
#         <Axes: title={'center': 'SleepTime'}>,
#         <Axes: title={'center': 'Asthma'}>],
#        [<Axes: title={'center': 'KidneyDisease'}>,
#         <Axes: title={'center': 'SkinCancer'}>, <Axes: >]], dtype=object)

# %%
sns.pairplot(df)

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# **Decide X and Y**

# %%
x=df.drop('HeartDisease',axis=1)
y=df['HeartDisease']

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223856 entries, 303145 to 121958
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   BMI              223856 non-null  float64
#  1   Smoking          223856 non-null  int64
#  2   AlcoholDrinking  223856 non-null  int64
#  3   Stroke           223856 non-null  int64
#  4   Sex              223856 non-null  int64
#  5   Diabetic         223856 non-null  int64
#  6   SleepTime        223856 non-null  int64
#  7   Asthma           223856 non-null  int64
#  8   KidneyDisease    223856 non-null  int64
#  9   SkinCancer       223856 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 18.8 MB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95939 entries, 271884 to 142745
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BMI              95939 non-null  float64
#  1   Smoking          95939 non-null  int64
#  2   AlcoholDrinking  95939 non-null  int64
#  3   Stroke           95939 non-null  int64
#  4   Sex              95939 non-null  int64
#  5   Diabetic         95939 non-null  int64
#  6   SleepTime        95939 non-null  int64
#  7   Asthma           95939 non-null  int64
#  8   KidneyDisease    95939 non-null  int64
#  9   SkinCancer       95939 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 8.1 MB

# %% [markdown]
# **Machine Learning Models**

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logmodel.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     87649
#            1       0.53      0.06      0.11      8290
#
#     accuracy                           0.91     95939
#    macro avg       0.72      0.53      0.53     95939
# weighted avg       0.88      0.91      0.88     95939

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[87206   443]
#  [ 7789   501]]
